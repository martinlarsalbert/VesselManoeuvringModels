# %% [markdown]
# # MDL Twin simulations: Select runs
# This notebooks makes a selection of runs from the MDL DB, to be used in the twin simulations

# %%
#import data
from mdldb.mdl_db import MDLDataBase
from mdldb.tables import Base, Model, LoadingCondition, Project, Ship
from mdldb.run import Run
from mdldb.authenticate import authenticate
import pandas as pd
pd.options.display.max_rows = 999
pd.options.display.max_columns = 999
pd.set_option("display.max_columns", None)
import warnings
import numpy as np
# Out:
# Duplicate key in file WindowsPath('C:/Users/maa/.matplotlib/stylelib/paper.mplstyle'), line 463 ('figure.dpi       : 100        ## figure dots per inch')

# %% [markdown]
# ## Get MDL runs

# %%
authenticate(dotenv_path='../.env')
db = MDLDataBase()

# %%
project = db.session.query(Project).get(40199079)
# Out:
# <ipython-input-3-99acc3611b7c>:1: SAWarning: relationship 'Ship.projects' will copy column ships.name to column association.ship_name, which conflicts with relationship(s): 'Project.ships' (copies ships.name to association.ship_name). If this is not the intention, consider if these relationships should be linked with back_populates, or if viewonly=True should be applied to one or more if they are read-only. For the less common case that foreign key constraints are partially overlapping, the orm.foreign() annotation can be used to isolate the columns that should be written towards.   The 'overlaps' parameter may be used to remove this warning.
#   project = db.session.query(Project).get(40199079)
# ...

# %%
query = db.session.query(Run,Model,LoadingCondition,Ship).filter((Run.project==project)).join(
    Model, Run.model_number == Model.model_number).join(
    LoadingCondition, Run.loading_condition_id==LoadingCondition.id).join(
    Ship, Run.ship_name==Ship.name)

df_all = pd.read_sql(query.statement, db.engine)
df_all.drop(columns=['model_number_1','model_number_2','id_1','name_1','ship_name_1'], inplace=True)
df_all.set_index('id', inplace=True)
display(df_all.head())
display(df_all.tail())
# Out:
#        project_number  series_number  run_number  test_number model_number  \
# id
# 22563        40199079              0           1            1   M5139-02-A
# 22564        40199079              0           2            1   M5139-02-A
# 22565        40199079              0           1            2   M5139-02-A
# 22566        40199079              0           2            2   M5139-02-A
# 22567        40199079              0           1            3   M5139-02-A
#
#         ship_name  loading_condition_id ascii_name  ship_speed    comment  \
# id
# 22563  M5139-02-A                   167       None         NaN  lam/l=0.5
# 22564  M5139-02-A                   167       None         NaN  lam/l=0.5
# 22565  M5139-02-A                   167       None         NaN  lam/l=0.7
# 22566  M5139-02-A                   167       None         NaN  lam/l=0.7
# 22567  M5139-02-A                   167       None         NaN  lam/l=0.9
#
#       file_path_ascii file_path_ascii_temp file_path_log  \
# ...

# %%
df_all.describe()
# Out:
#        project_number  series_number  run_number  test_number  \
# count           313.0     313.000000  313.000000   313.000000
# mean       40199079.0       4.338658    3.936102   185.731629
# std               0.0       3.481684    4.026643   378.520159
# min        40199079.0       0.000000    1.000000     1.000000
# 25%        40199079.0       1.000000    1.000000     6.000000
# 50%        40199079.0       4.000000    2.000000     9.000000
# 75%        40199079.0       6.000000    5.000000    18.000000
# max        40199079.0      10.000000   22.000000   999.000000
#
#        loading_condition_id  ship_speed     angle1     angle2  scale_factor  \
# count                 313.0  214.000000  18.000000  18.000000  3.130000e+02
# mean                  167.0   11.768692  13.333333  13.333333  4.120000e+01
# std                     0.0    1.985629   4.850713   4.850713  7.116805e-15
# min                   167.0    0.000000  10.000000  10.000000  4.120000e+01
# ...

# %%
df_all['test_type'].unique()
# Out:
# array(['wave calibration', 'GM', 'roll decay', 'reference speed',
#        'rodergrundvinkel', 'unknown', 'SMEG', 'seakeeping', 'zigzag',
#        'turning circle'], dtype=object)

# %%
df_all.groupby(by='test_type').get_group('unknown')
# Out:
#        project_number  series_number  run_number  test_number model_number  \
# id
# 22640        40199079              1           1          888   M5139-02-A
# 22641        40199079              1           2          888   M5139-02-A
# 22784        40199079              6           1            1   M5139-02-A
# 22785        40199079              6           2            1   M5139-02-A
# 22786        40199079              6           3            1   M5139-02-A
# 22787        40199079              6           1            2   M5139-02-A
# 22788        40199079              6           1            3   M5139-02-A
# 22789        40199079              6           1            4   M5139-02-A
# 22790        40199079              6           1            5   M5139-02-A
# 22791        40199079              6           1            6   M5139-02-A
# 22792        40199079              6           2            6   M5139-02-A
# ...

# %%
mask = df_all['comment'].str.contains('Seglande')
df_all.loc[mask,'test_type'] = 'sailing'

# %%
df_all['series_number'].unique()
# Out:
# array([ 0,  1,  2,  3,  4,  5,  6, 10], dtype=int64)

# %% [markdown]
# ## Not zero speed

# %%
df_select = df_all.dropna(subset=['ship_speed'])
mask = df_select['ship_speed'] > 0
df_select = df_select.loc[mask].copy()

# %%
df_select['ship_speed'].unique()
# Out:
# array([12. , 10. ,  8. , 16. ,  9. , 11. , 13.8, 15.8, 14. , 11.5])

# %% [markdown]
# ## test type

# %%
wanted_test_types = ['reference speed',
                    'rodergrundvinkel',
                    'sailing',
                    'zigzag',
                    'turning circle']
mask = df_select['test_type'].isin(wanted_test_types)
df_select = df_select.loc[mask].copy()

# %%
df_select['comment'].unique()
# Out:
# array(['12.0 kn', 'Rodergrundvinkel', 'Kal fläktstyrning', '10.0 kn',
#        '8.0 kn', 'ZZ 10/10SB', 'ZZ 10/10PS', 'ZZ 20/20SB', 'ZZ 20/20PS',
#        'Circle 35SB', 'Circle 35PS', 'ZZ 10/10SB - GWA= -90',
#        'ZZ 10/10PS - GWA= -90', 'ZZ 20/20SB - GWA= -90',
#        'ZZ 20/20PS - GWA= -90', 'Seglande 55deg', 'Seglande 120deg',
#        'Seglande GWA= -90deg'], dtype=object)

# %%
unwanted_comments = [
    'Kal fläktstyrning',
#    'ZZ 10/10SB - GWA= -90',
#    'ZZ 10/10PS - GWA= -90',
#    'ZZ 20/20SB - GWA= -90',
#    'ZZ 20/20PS - GWA= -90'
]
mask = df_select['comment'].isin(unwanted_comments)
df_select = df_select.loc[~mask].copy()

# %%
df_select.describe()
# Out:
#        project_number  series_number  run_number  test_number  \
# count            86.0      86.000000   86.000000    86.000000
# mean       40199079.0       6.581395    4.930233     9.104651
# std               0.0       3.789972    5.217145     4.508891
# min        40199079.0       1.000000    1.000000     1.000000
# 25%        40199079.0       5.000000    2.000000     7.000000
# 50%        40199079.0      10.000000    3.000000     8.000000
# 75%        40199079.0      10.000000    5.000000    10.000000
# max        40199079.0      10.000000   22.000000    18.000000
#
#        loading_condition_id  ship_speed     angle1     angle2  scale_factor  \
# count                  86.0   86.000000  18.000000  18.000000  8.600000e+01
# mean                  167.0   12.284884  13.333333  13.333333  4.120000e+01
# std                     0.0    1.502431   4.850713   4.850713  2.144131e-14
# min                   167.0    8.000000  10.000000  10.000000  4.120000e+01
# ...

# %% [markdown]
# ## To model scale

# %%
df_select.iloc[0].dropna()
# Out:
# project_number                                                   40199079
# series_number                                                           1
# run_number                                                              1
# test_number                                                             7
# model_number                                                   M5139-02-A
# ship_name                                                      M5139-02-A
# loading_condition_id                                                  167
# ship_speed                                                           12.0
# comment                                                           12.0 kn
# file_path_hdf5          \\sspa.local\lab\MeasuredataMDL\40199079\001\0...
# date                                                           2020-09-18
# test_type                                                 reference speed
# facility                                                              MDL
# ...

# %%
df_select_model_scale = df_select.copy()
scale_factor = df_select_model_scale['scale_factor']
units = {}

df_select_model_scale['ship_speed']*=1.852/3.6*1/np.sqrt(scale_factor)
units['ship_speed'] = r'm/s'

df_select_model_scale['Volume']*=1/(scale_factor**3)
units['Volume'] = r'm^3'

meters = ['lcg','kg','gm','TF','TA','KXX','KZZ','lpp','beam']
for key in meters:
    df_select_model_scale[key]*=1/scale_factor
    units[key] = r'm'

# %%
df_select_model_scale['xm'] = 0
df_select_model_scale['ym'] = 0
df_select_model_scale['zm'] = -0.214
units['xm'] = 'm'
units['ym'] = 'm'
units['zm'] = 'm'

# %% [markdown]
# ## Save

# %%
df_select_model_scale.to_csv('../data/interim/run_selection.csv')
pd.Series(units).to_csv('../data/raw/units.csv')
